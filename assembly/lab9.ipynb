# %% [markdown]
# ## Lab 9: Sequence Assembly
#
# This report and the data used for it can be found at https://github.com/abondrn/compbio-labs/tree/master/assembly.
#
# Using SPAdes, you will assemble a bacterial genome de novo using a combination of long PacBio reads and short Illumina reads. Next week, you will analyze your genome to determine the species and obtain an overview of its metabolism. You are expected to keep a thorough record of everything you did in your notebook.
#
# References
#  - [Sequence assembly](https://en.wikipedia.org/wiki/Sequence_assembly)
#  - [SPAdes](http://cab.spbu.ru/files/release3.12.0/manual.html)
#  - [PacBio SMRT Sequencing](https://en.wikipedia.org/wiki/Single_molecule_real_time_sequencing)
#  - [Illumina sequencing](https://en.wikipedia.org/wiki/Illumina_dye_sequencing)
#
# ## Background
#
# Genome sequencing and assembly arecommon techniques in biology. To obtain the sequence of a long genome, DNA must be chopped into small pieces that can be read by a sequencer. These short reads must then be stitched back together to form acomplete genome.Often, the genome cannot be fully assembled because there are multiple equally plausible ways of stitching the reads together. Ideally, each chromosome is assembled into a single, long sequence. In practice, chromosomes are often assembled into multiple “contigs,” or contiguous sequences. A genome assembly is generally considered complete only when all (or nearly all) the sequences are accounted for. Otherwise, it is considered a draft genome.
#
# In this lab, you will assemble and analysis a bacterial genome, using Illumina and PacBio reads. This week, you will take the reads and assemble them into a complete genome. Next week, you will analyze the contents of your genome.
#
# ## Locating the data
#
# DNA from an unknown bacterium was sequenced using PacBio and Illumina technologies. The resulting reads are uploaded onto bCourses. You will need to download these files. You will need to upload the files if you are using DataHub.
#
# `illumina_reads_R1.fastq` – first paired-end read \
# `illumina_reads_R2.fastq` – second paired-end read \
# `pacbio_reads.fastq` – long PacBio reads

# %%
# !bzip2 -dk reads/*.fastq.bz2
# Out:
# bzip2: Output file reads/illumina_reads_R1.fastq already exists.
# bzip2: Output file reads/illumina_reads_R2.fastq already exists.

# %% [markdown]
# ## Running SPAdes
#
# SPAdes is a hybrid genome assembler, meaning that it takes multiple sources of information as input and combines them to produce an optimal assembly. Assemblies using only short reads tend to be highly fragmented (i.e., many contigs). Assemblies using a high-quality short read set and a higher error rate long-read set (like PacBio) tend to be the best.
#
# **Why do we expect short reads to produce a more fragmented assembly than long reads?**
#
# > We would expect short reads to result in more fragmented assemblies because the shortness of the input leads to a higher amount of contigs versus long reads, which would increase the likelihood of there being gaps between reads, thus splitting up the assembly.
#
# **Why does a single-molecule sequencing like PacBio have a higher error rate than Illumina?**
#
# > Illuma uses many small reads versus the individual long strands used in SMRT. Thus, in the case of inevitable misreads, Illumina can use multiple overlaping contigs for the same reading frame thus having a greater coverage than the equivalent PacBio sequencing and reducing error.
#
# We need to come up with a SPAdes command. At a minimum, you will need to specify the output directory with -o, the path to the first Illumina read with -1, the path to the second Illumina read with -2, and the path to your PacBio reads with --pacbio. Note: SPAdes must be run from the command line, and can take a while.
#
# Genome assembly requires a relatively large amount of computer memory. Sometimes up to 1TB. Datahub instances have 64GB of memory. We have significantly subsampled the reads in order to run the analysis on DataHub.
#
# SPAdes typically uses multi-threading to speed up assembly. Each thread requires memory. You may need to add -t 4 to your command so that it uses only 4 threads on the system rather than 16. If the program crashes, reduce the number of threads.

# %%
# !spades.py -1 reads/illumina_reads_R1.fastq -2 reads/illumina_reads_R2.fastq --pacbio reads/pacbio_reads.fastq -o spades -t 4
# Out:
# == Warning ==  No assembly mode was specified! If you intend to assemble high-coverage multi-cell/isolate data, use '--isolate' option.
#
#
# Command line: /opt/conda/bin/spades.py	-1	/home/jovyan/compbio-labs/assembly/reads/illumina_reads_R1.fastq	-2	/home/jovyan/compbio-labs/assembly/reads/illumina_reads_R2.fastq	--pacbio	/home/jovyan/compbio-labs/assembly/reads/pacbio_reads.fastq	-o	/home/jovyan/compbio-labs/assembly/spades	-t	4
#
# System information:
#   SPAdes version: 3.14.1
#   Python version: 3.8.6
#   OS: Linux-5.3.0-1036-gke-x86_64-with-glibc2.10
#
# Output dir: /home/jovyan/compbio-labs/assembly/spades
# Mode: read error correction and assembling
# Debug mode is turned OFF
#
# Dataset parameters:
#   Standard mode
#   For multi-cell/isolate data we recommend to use '--isolate' option; for single-cell MDA data use '--sc'; for metagenomic data use '--meta'; for RNA-Seq use '--rna'.
#   Reads:
#     Library number: 1, library type: paired-end
#       orientation: fr
#       left reads: ['/home/jovyan/compbio-labs/assembly/reads/illumina_reads_R1.fastq']
#       right reads: ['/home/jovyan/compbio-labs/assembly/reads/illumina_reads_R2.fastq']
#       interlaced reads: not specified
#       single reads: not specified
#       merged reads: not specified
#     Library number: 2, library type: pacbio
#       left reads: not specified
#       right reads: not specified
#       interlaced reads: not specified
#       single reads: ['/home/jovyan/compbio-labs/assembly/reads/pacbio_reads.fastq']
#       merged reads: not specified
# Read error correction parameters:
#   Iterations: 1
#   PHRED offset will be auto-detected
#   Corrected reads will be compressed
# Assembly parameters:
#   k: automatic selection based on read length
#   Repeat resolution is enabled
#   Mismatch careful mode is turned OFF
#   MismatchCorrector will be SKIPPED
#   Coverage cutoff is turned OFF
# Other parameters:
#   Dir for temp files: /home/jovyan/compbio-labs/assembly/spades/tmp
#   Threads: 4
#   Memory limit (in Gb): 51
#
#
# ======= SPAdes pipeline started. Log can be found here: /home/jovyan/compbio-labs/assembly/spades/spades.log
#
# /home/jovyan/compbio-labs/assembly/reads/illumina_reads_R1.fastq: max reads length: 300
# /home/jovyan/compbio-labs/assembly/reads/illumina_reads_R2.fastq: max reads length: 300
#
# Reads length: 300
#
# Default k-mer sizes were set to [21, 33, 55, 77, 99, 127] because estimated read length (300) is equal to or greater than 250
#
# ===== Before start started.
#
#
# ===== Read error correction started.
#
#
# ===== Read error correction started.
#
#
# == Running: /opt/conda/bin/spades-hammer /home/jovyan/compbio-labs/assembly/spades/corrected/configs/config.info
#
#   0:00:00.000     4M / 12M   INFO    General                 (main.cpp                  :  75)   Starting BayesHammer, built from N/A, git revision N/A
#   0:00:00.000     4M / 12M   INFO    General                 (main.cpp                  :  76)   Loading config from /home/jovyan/compbio-labs/assembly/spades/corrected/configs/config.info
#   0:00:00.003     4M / 12M   INFO    General                 (main.cpp                  :  78)   Maximum # of threads to use (adjusted due to OMP capabilities): 4
#   0:00:00.003     4M / 12M   INFO    General                 (memory_limit.cpp          :  49)   Memory limit set to 51 Gb
#   0:00:00.003     4M / 12M   INFO    General                 (main.cpp                  :  86)   Trying to determine PHRED offset
#   0:00:00.003     4M / 12M   INFO    General                 (main.cpp                  :  92)   Determined value is 33
#   0:00:00.003     4M / 12M   INFO    General                 (hammer_tools.cpp          :  38)   Hamming graph threshold tau=1, k=21, subkmer positions = [ 0 10 ]
#   0:00:00.003     4M / 12M   INFO    General                 (main.cpp                  : 113)   Size of aux. kmer data 24 bytes
#      === ITERATION 0 begins ===
#   0:00:00.009     4M / 12M   INFO   K-mer Index Building     (kmer_index_builder.hpp    : 301)   Building kmer index
#   0:00:00.009     4M / 12M   INFO    General                 (kmer_index_builder.hpp    : 117)   Splitting kmer instances into 64 files using 4 threads. This might take a while.
#   0:00:00.011     4M / 12M   INFO    General                 (file_limit.hpp            :  32)   Open file limit set to 1048576
#   0:00:00.011     4M / 12M   INFO    General                 (kmer_splitters.hpp        :  89)   Memory available for splitting buffers: 4.24995 Gb
#   0:00:00.011     4M / 12M   INFO    General                 (kmer_splitters.hpp        :  97)   Using cell size of 1048576
#   0:00:00.012     3G / 3G    INFO   K-mer Splitting          (kmer_data.cpp             :  97)   Processing /home/jovyan/compbio-labs/assembly/reads/illumina_reads_R1.fastq
#   0:00:02.500     3G / 3G    INFO   K-mer Splitting          (kmer_data.cpp             : 107)   Processed 56689 reads
#   0:00:02.501     3G / 3G    INFO   K-mer Splitting          (kmer_data.cpp             :  97)   Processing /home/jovyan/compbio-labs/assembly/reads/illumina_reads_R2.fastq
#   0:00:04.922     3G / 3G    INFO   K-mer Splitting          (kmer_data.cpp             : 107)   Processed 113378 reads
#   0:00:04.923     3G / 3G    INFO   K-mer Splitting          (kmer_data.cpp             : 112)   Total 113378 reads processed
#   0:00:04.943    51M / 301M  INFO    General                 (kmer_index_builder.hpp    : 120)   Starting k-mer counting.
#   0:00:07.186    46M / 301M  INFO    General                 (kmer_index_builder.hpp    : 127)   K-mer counting done. There are 46781970 kmers in total.
#   0:00:07.186    46M / 301M  INFO    General                 (kmer_index_builder.hpp    : 133)   Merging temporary buckets.
#   0:00:09.656    46M / 301M  INFO   K-mer Index Building     (kmer_index_builder.hpp    : 314)   Building perfect hash indices
#   0:00:12.876    55M / 301M  INFO    General                 (kmer_index_builder.hpp    : 150)   Merging final buckets.
#   0:00:15.522    55M / 301M  INFO   K-mer Index Building     (kmer_index_builder.hpp    : 336)   Index built. Total 21700984 bytes occupied (3.711 bits per kmer).
#   0:00:15.526    55M / 301M  INFO   K-mer Counting           (kmer_data.cpp             : 351)   Arranging kmers in hash map order
#   0:00:18.677   823M / 823M  INFO    General                 (main.cpp                  : 148)   Clustering Hamming graph.
#   0:02:26.529   823M / 823M  INFO    General                 (main.cpp                  : 155)   Extracting clusters
#   0:02:42.808     2G / 3G    INFO    General                 (main.cpp                  : 167)   Clustering done. Total clusters: 38441779
#   0:02:42.827   705M / 3G    INFO   K-mer Counting           (kmer_data.cpp             : 371)   Collecting K-mer information, this takes a while.
#   0:02:43.510     2G / 3G    INFO   K-mer Counting           (kmer_data.cpp             : 377)   Processing /home/jovyan/compbio-labs/assembly/reads/illumina_reads_R1.fastq
#   0:02:50.235     2G / 3G    INFO   K-mer Counting           (kmer_data.cpp             : 377)   Processing /home/jovyan/compbio-labs/assembly/reads/illumina_reads_R2.fastq
#   0:02:57.022     2G / 3G    INFO   K-mer Counting           (kmer_data.cpp             : 384)   Collection done, postprocessing.
#   0:02:57.172     2G / 3G    INFO   K-mer Counting           (kmer_data.cpp             : 398)   There are 46781970 kmers in total. Among them 42546276 (90.9459%) are singletons.
#   0:02:57.172     2G / 3G    INFO    General                 (main.cpp                  : 173)   Subclustering Hamming graph
#   0:07:34.284     2G / 3G    INFO   Hamming Subclustering    (kmer_cluster.cpp          : 649)   Subclustering done. Total 1783 non-read kmers were generated.
#   0:07:34.284     2G / 3G    INFO   Hamming Subclustering    (kmer_cluster.cpp          : 650)   Subclustering statistics:
#   0:07:34.284     2G / 3G    INFO   Hamming Subclustering    (kmer_cluster.cpp          : 651)     Total singleton hamming clusters: 35967378. Among them 2981506 (8.28947%) are good
#   0:07:34.285     2G / 3G    INFO   Hamming Subclustering    (kmer_cluster.cpp          : 652)     Total singleton subclusters: 599. Among them 525 (87.6461%) are good
#   0:07:34.285     2G / 3G    INFO   Hamming Subclustering    (kmer_cluster.cpp          : 653)     Total non-singleton subcluster centers: 2521603. Among them 114785 (4.55206%) are good
#   0:07:34.285     2G / 3G    INFO   Hamming Subclustering    (kmer_cluster.cpp          : 654)     Average size of non-trivial subcluster: 4.29277 kmers
#   0:07:34.285     2G / 3G    INFO   Hamming Subclustering    (kmer_cluster.cpp          : 655)     Average number of sub-clusters per non-singleton cluster: 1.01932
#   0:07:34.285     2G / 3G    INFO   Hamming Subclustering    (kmer_cluster.cpp          : 656)     Total solid k-mers: 3096816
#   0:07:34.285     2G / 3G    INFO   Hamming Subclustering    (kmer_cluster.cpp          : 657)     Substitution probabilities: [4,4]((0.855005,0.0629047,0.0322355,0.0498549),(0.0400336,0.887204,0.0286099,0.0441525),(0.0338771,0.0215413,0.888781,0.0558003),(0.0464257,0.0292394,0.0590673,0.865268))
#   0:07:34.353     2G / 3G    INFO    General                 (main.cpp                  : 178)   Finished clustering.
#   0:07:34.353     2G / 3G    INFO    General                 (main.cpp                  : 197)   Starting solid k-mers expansion in 4 threads.
#   0:07:38.559     2G / 3G    INFO    General                 (main.cpp                  : 218)   Solid k-mers iteration 0 produced 1909 new k-mers.
#   0:07:42.595     2G / 3G    INFO    General                 (main.cpp                  : 218)   Solid k-mers iteration 1 produced 0 new k-mers.
#   0:07:42.595     2G / 3G    INFO    General                 (main.cpp                  : 222)   Solid k-mers finalized
#   0:07:42.595     2G / 3G    INFO    General                 (hammer_tools.cpp          : 222)   Starting read correction in 4 threads.
#   0:07:42.596     2G / 3G    INFO    General                 (hammer_tools.cpp          : 235)   Correcting pair of reads: /home/jovyan/compbio-labs/assembly/reads/illumina_reads_R1.fastq and /home/jovyan/compbio-labs/assembly/reads/illumina_reads_R2.fastq
#   0:07:43.179     2G / 3G    INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 0 of 56689 reads.
#   0:17:27.157     2G / 3G    INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 0
#   0:17:27.313     2G / 3G    INFO    General                 (hammer_tools.cpp          : 187)   Written batch 0
#   0:17:27.768     2G / 3G    INFO    General                 (hammer_tools.cpp          : 276)   Correction done. Changed 451482 bases in 40044 reads.
#   0:17:27.768     2G / 3G    INFO    General                 (hammer_tools.cpp          : 277)   Failed to correct 52007 bases out of 33818112.
#   0:17:27.846   161M / 3G    INFO    General                 (main.cpp                  : 255)   Saving corrected dataset description to /home/jovyan/compbio-labs/assembly/spades/corrected/corrected.yaml
#   0:17:27.851   161M / 3G    INFO    General                 (main.cpp                  : 262)   All done. Exiting.
#
# ===== Read error correction finished.
#
#
# ===== corrected reads compression started.
#
#
# == Running: /opt/conda/bin/python /opt/conda/share/spades/spades_pipeline/scripts/compress_all.py --input_file /home/jovyan/compbio-labs/assembly/spades/corrected/corrected.yaml --ext_python_modules_home /opt/conda/share/spades --max_threads 4 --output_dir /home/jovyan/compbio-labs/assembly/spades/corrected --not_used_yaml_file /home/jovyan/compbio-labs/assembly/spades/corrected/dont_correct.yaml --gzip_output
#
# == Compressing corrected reads (with gzip)
# == Files to compress: ['/home/jovyan/compbio-labs/assembly/spades/corrected/illumina_reads_R1.00.0_0.cor.fastq', '/home/jovyan/compbio-labs/assembly/spades/corrected/illumina_reads_R2.00.0_0.cor.fastq', '/home/jovyan/compbio-labs/assembly/spades/corrected/illumina_reads_R_unpaired.00.0_0.cor.fastq']
# == Files compression is finished
# == Info about datasets not used in error correction stage is loaded
# == Dataset yaml file is updated
#
# ===== corrected reads compression finished.
#
#
# ===== Read error correction finished.
#
#
# ===== Assembling started.
#
#
# ===== K21 started.
#
#
# == Running: /opt/conda/bin/spades-core /home/jovyan/compbio-labs/assembly/spades/K21/configs/config.info
#
# WARNING: Try to use logger before create one. Level=INFO. Message=Additional contigs is tmp_contigs.fasta
#   0:00:00.000     4M / 12M   INFO    General                 (main.cpp                  :  75)   Loaded config from /home/jovyan/compbio-labs/assembly/spades/K21/configs/config.info
#   0:00:00.000     4M / 12M   INFO    General                 (memory_limit.cpp          :  49)   Memory limit set to 51 Gb
#   0:00:00.000     4M / 12M   INFO    General                 (main.cpp                  :  85)   Starting SPAdes, built from N/A, git revision N/A
#   0:00:00.000     4M / 12M   INFO    General                 (main.cpp                  :  86)   Maximum k-mer length: 128
#   0:00:00.000     4M / 12M   INFO    General                 (main.cpp                  :  87)   Assembling dataset (/home/jovyan/compbio-labs/assembly/spades/dataset.info) with K=21
#   0:00:00.000     4M / 12M   INFO    General                 (main.cpp                  :  88)   Maximum # of threads to use (adjusted due to OMP capabilities): 4
#   0:00:00.000     4M / 12M   INFO    General                 (pipeline.cpp              : 194)   SPAdes started
#   0:00:00.000     4M / 12M   INFO    General                 (pipeline.cpp              : 201)   Starting from stage: read_conversion
#   0:00:00.000     4M / 12M   INFO    General                 (pipeline.cpp              : 207)   Two-step RR enabled: 0
#   0:00:00.001     4M / 12M   INFO   StageManager             (stage.cpp                 : 166)   STAGE == Binary Read Conversion
#   0:00:00.005     4M / 12M   INFO    General                 (read_converter.cpp        :  72)   Converting reads to binary format for library #0 (takes a while)
#   0:00:00.005     4M / 12M   INFO    General                 (read_converter.cpp        :  73)   Converting paired reads
#   0:00:01.166   166M / 166M  INFO    General                 (binary_converter.cpp      :  96)   16384 reads processed
#   0:00:01.281   188M / 188M  INFO    General                 (binary_converter.cpp      :  96)   32768 reads processed
#   0:00:01.777   218M / 218M  INFO    General                 (binary_converter.cpp      : 111)   55070 reads written
#   0:00:01.778   194M / 194M  INFO    General                 (read_converter.cpp        :  81)   Converting single reads
#   0:00:01.810   228M / 228M  INFO    General                 (binary_converter.cpp      : 111)   1561 reads written
#   0:00:01.810   218M / 218M  INFO    General                 (read_converter.cpp        :  87)   Converting merged reads
#   0:00:01.814   228M / 228M  INFO    General                 (binary_converter.cpp      : 111)   0 reads written
#   0:00:01.871   158M / 181M  INFO    General                 (read_converter.cpp        :  72)   Converting reads to binary format for library #1 (takes a while)
#   0:00:01.871   158M / 181M  INFO    General                 (read_converter.cpp        :  73)   Converting paired reads
#   0:00:01.873   182M / 182M  INFO    General                 (binary_converter.cpp      : 111)   0 reads written
#   0:00:01.874   158M / 181M  INFO    General                 (read_converter.cpp        :  81)   Converting single reads
#   0:00:03.835   327M / 327M  INFO    General                 (binary_converter.cpp      : 111)   8182 reads written
#   0:00:03.835   317M / 317M  INFO    General                 (read_converter.cpp        :  87)   Converting merged reads
#   0:00:03.839   327M / 327M  INFO    General                 (binary_converter.cpp      : 111)   0 reads written
#   0:00:03.913   110M / 304M  INFO   StageManager             (stage.cpp                 : 166)   STAGE == de Bruijn graph construction
#   0:00:03.924   110M / 304M  INFO    General                 (construction.cpp          : 150)   Max read length 300
#   0:00:03.924   110M / 304M  INFO    General                 (construction.cpp          : 156)   Average read length 298.125
#   0:00:03.924   110M / 304M  INFO    General                 (stage.cpp                 : 113)   PROCEDURE == k+1-mer counting
#   0:00:03.927   110M / 304M  INFO    General                 (kmer_index_builder.hpp    : 117)   Splitting kmer instances into 16 files using 4 threads. This might take a while.
#   0:00:03.930   110M / 304M  INFO    General                 (file_limit.hpp            :  32)   Open file limit set to 1048576
#   0:00:03.930   110M / 304M  INFO    General                 (kmer_splitters.hpp        :  89)   Memory available for splitting buffers: 4.24964 Gb
#   0:00:03.930   110M / 304M  INFO    General                 (kmer_splitters.hpp        :  97)   Using cell size of 4194304
#   0:00:06.283     3G / 3G    INFO    General                 (kmer_splitters.hpp        : 287)   Processed 223402 reads
#   0:00:06.301   111M / 405M  INFO    General                 (kmer_splitters.hpp        : 293)   Used 223402 reads
#   0:00:06.301   111M / 405M  INFO    General                 (kmer_index_builder.hpp    : 120)   Starting k-mer counting.
#   0:00:07.483   111M / 405M  INFO    General                 (kmer_index_builder.hpp    : 127)   K-mer counting done. There are 21443728 kmers in total.
#   0:00:07.483   111M / 405M  INFO    General                 (kmer_index_builder.hpp    : 133)   Merging temporary buckets.
#   0:00:08.697   111M / 405M  INFO    General                 (stage.cpp                 : 113)   PROCEDURE == Extension index construction
#   0:00:08.700   111M / 405M  INFO   K-mer Index Building     (kmer_index_builder.hpp    : 301)   Building kmer index
#   0:00:08.700   111M / 405M  INFO    General                 (kmer_index_builder.hpp    : 117)   Splitting kmer instances into 64 files using 4 threads. This might take a while.
#   0:00:08.703   111M / 405M  INFO    General                 (file_limit.hpp            :  32)   Open file limit set to 1048576
#   0:00:08.703   111M / 405M  INFO    General                 (kmer_splitters.hpp        :  89)   Memory available for splitting buffers: 4.24993 Gb
#   0:00:08.703   111M / 405M  INFO    General                 (kmer_splitters.hpp        :  97)   Using cell size of 1048576
#   0:00:12.348     3G / 3G    INFO    General                 (kmer_splitters.hpp        : 364)   Processed 21443728 kmers
#   0:00:12.349     3G / 3G    INFO    General                 (kmer_splitters.hpp        : 369)   Used 21443728 kmers.
#   0:00:12.382   135M / 621M  INFO    General                 (kmer_index_builder.hpp    : 120)   Starting k-mer counting.
#   0:00:13.437    34M / 621M  INFO    General                 (kmer_index_builder.hpp    : 127)   K-mer counting done. There are 21133649 kmers in total.
#   0:00:13.437    34M / 621M  INFO    General                 (kmer_index_builder.hpp    : 133)   Merging temporary buckets.
#   0:00:14.511    34M / 621M  INFO   K-mer Index Building     (kmer_index_builder.hpp    : 314)   Building perfect hash indices
#   0:00:15.841    39M / 621M  INFO    General                 (kmer_index_builder.hpp    : 150)   Merging final buckets.
#   0:00:17.045    39M / 621M  INFO   K-mer Index Building     (kmer_index_builder.hpp    : 336)   Index built. Total 9807920 bytes occupied (3.71272 bits per kmer).
#   0:00:17.065    63M / 621M  INFO   DeBruijnExtensionIndexBu (kmer_extension_index_build:  99)   Building k-mer extensions from k+1-mers
#   0:00:20.479    63M / 621M  INFO   DeBruijnExtensionIndexBu (kmer_extension_index_build: 103)   Building k-mer extensions from k+1-mers finished.
#   0:00:20.481    63M / 621M  INFO    General                 (stage.cpp                 : 113)   PROCEDURE == Early tip clipping
#   0:00:20.481    63M / 621M  INFO    General                 (construction.cpp          : 293)   Early tip clipper length bound set as (RL - K)
#   0:00:20.481    63M / 621M  INFO   Early tip clipping       (early_simplification.hpp  :  28)   Early tip clipping
#   0:00:24.497    65M / 621M  INFO   Early tip clipping       (early_simplification.hpp  :  63)   #tipped junctions: 89766
#   0:00:24.516    65M / 621M  INFO   Early tip clipping       (early_simplification.hpp  :  74)   Clipped tips: 91791
#   0:00:24.524    65M / 621M  INFO   Early tip clipping       (early_simplification.hpp  :  30)   8810540 22-mers were removed by early tip clipper
#   0:00:24.524    65M / 621M  INFO    General                 (stage.cpp                 : 113)   PROCEDURE == Condensing graph
#   0:00:24.539    65M / 621M  INFO   UnbranchingPathExtractor (debruijn_graph_constructor: 354)   Extracting unbranching paths
#   0:00:28.223   123M / 621M  INFO   UnbranchingPathExtractor (debruijn_graph_constructor: 373)   Extracting unbranching paths finished. 717762 sequences extracted
#   0:00:29.901   123M / 621M  INFO   UnbranchingPathExtractor (debruijn_graph_constructor: 309)   Collecting perfect loops
#   0:00:30.854   123M / 621M  INFO   UnbranchingPathExtractor (debruijn_graph_constructor: 342)   Collecting perfect loops finished. 1 loops collected
#   0:00:31.547   275M / 621M  INFO    General                 (stage.cpp                 : 113)   PROCEDURE == Filling coverage indices (PHM)
#   0:00:31.547   275M / 621M  INFO   K-mer Index Building     (kmer_index_builder.hpp    : 301)   Building kmer index
#   0:00:31.548   275M / 621M  INFO   K-mer Index Building     (kmer_index_builder.hpp    : 314)   Building perfect hash indices
#   0:00:32.964   275M / 621M  INFO   K-mer Index Building     (kmer_index_builder.hpp    : 336)   Index built. Total 9945432 bytes occupied (3.71034 bits per kmer).
#   0:00:33.016   371M / 621M  INFO    General                 (construction.cpp          : 429)   Collecting k-mer coverage information from reads, this takes a while.
#   0:00:35.500   371M / 621M  INFO    General                 (construction.cpp          : 549)   Filling coverage and flanking coverage from PHM
#   0:00:37.888   371M / 621M  INFO    General                 (construction.cpp          : 505)   Processed 1435510 edges
#   0:00:37.965   251M / 621M  INFO   StageManager             (stage.cpp                 : 166)   STAGE == EC Threshold Finding
#   0:00:37.966   251M / 621M  INFO    General                 (kmer_coverage_model.cpp   : 181)   Kmer coverage valley at: 35
#   0:00:37.966   251M / 621M  INFO    General                 (kmer_coverage_model.cpp   : 201)   K-mer histogram maximum: 39
#   0:00:37.966   251M / 621M  INFO    General                 (kmer_coverage_model.cpp   : 237)   Estimated median coverage: 40. Coverage mad: 4.4478
#   0:00:37.966   251M / 621M  INFO    General                 (kmer_coverage_model.cpp   : 259)   Fitting coverage model
#   0:00:38.011   251M / 621M  INFO    General                 (kmer_coverage_model.cpp   : 295)   ... iteration 2
#   0:00:38.121   251M / 621M  INFO    General                 (kmer_coverage_model.cpp   : 295)   ... iteration 4
#   0:00:38.475   251M / 621M  INFO    General                 (kmer_coverage_model.cpp   : 295)   ... iteration 8
#   0:00:38.766   251M / 621M  INFO    General                 (kmer_coverage_model.cpp   : 295)   ... iteration 16
#   0:00:38.767   251M / 621M  INFO    General                 (kmer_coverage_model.cpp   : 309)   Fitted mean coverage: 177.09. Fitted coverage std. dev: 103.964
#   0:00:38.767   251M / 621M  INFO    General                 (kmer_coverage_model.cpp   : 334)   Probability of erroneous kmer at valley: 1
#   0:00:38.767   251M / 621M  WARN    General                 (kmer_coverage_model.cpp   : 366)   Failed to determine erroneous kmer threshold. Threshold set to: 35
#   0:00:38.768   251M / 621M  INFO    General                 (kmer_coverage_model.cpp   : 375)   Estimated genome size (ignoring repeats): 8614
#   0:00:38.768   251M / 621M  INFO    General                 (genomic_info_filler.cpp   :  55)   Failed to estimate mean coverage
#   0:00:38.768   251M / 621M  INFO    General                 (genomic_info_filler.cpp   :  68)   EC coverage threshold value was calculated as 35
#   0:00:38.768   251M / 621M  INFO    General                 (genomic_info_filler.cpp   :  69)   Trusted kmer low bound: 0
#   0:00:38.768   251M / 621M  INFO   StageManager             (stage.cpp                 : 166)   STAGE == Raw Simplification
#   0:00:38.768   251M / 621M  INFO    General                 (simplification.cpp        : 128)   PROCEDURE == InitialCleaning
#   0:00:38.769   251M / 621M  INFO    General                 (simplification.cpp        :  69)   Most init cleaning disabled since detected mean 0 was less than activation coverage 10
#   0:00:38.769   251M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Self conjugate edge remover
#   0:00:38.833   251M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Self conjugate edge remover triggered 0 times
#   0:00:38.833   251M / 621M  INFO   StageManager             (stage.cpp                 : 166)   STAGE == Simplification
#   0:00:38.833   251M / 621M  INFO    General                 (simplification.cpp        : 383)   Graph simplification started
#   0:00:38.833   251M / 621M  INFO    General                 (graph_simplification.hpp  : 643)   Creating parallel br instance
#   0:00:38.834   251M / 621M  INFO    General                 (simplification.cpp        : 388)   PROCEDURE == Simplification cycle, iteration 1
#   0:00:38.834   251M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Tip clipper
#   0:00:39.024   203M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Tip clipper triggered 4117 times
#   0:00:39.024   203M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Bulge remover
#   0:01:25.345   201M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Bulge remover triggered 16994 times
#   0:01:25.345   201M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Low coverage edge remover
#   0:01:30.145   199M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Low coverage edge remover triggered 287960 times
#   0:01:30.145   199M / 621M  INFO    General                 (simplification.cpp        : 388)   PROCEDURE == Simplification cycle, iteration 2
#   0:01:30.145   199M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Tip clipper
#   0:01:30.206   198M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Tip clipper triggered 5274 times
#   0:01:30.206   198M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Bulge remover
#   0:01:30.889   198M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Bulge remover triggered 97 times
#   0:01:30.889   198M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Low coverage edge remover
#   0:01:30.979   197M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Low coverage edge remover triggered 7972 times
#   0:01:30.979   197M / 621M  INFO    General                 (simplification.cpp        : 388)   PROCEDURE == Simplification cycle, iteration 3
#   0:01:30.979   197M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Tip clipper
#   0:01:30.982   197M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Tip clipper triggered 171 times
#   0:01:30.982   197M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Bulge remover
#   0:01:31.211   195M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Bulge remover triggered 36 times
#   0:01:31.211   195M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Low coverage edge remover
#   0:01:31.228   195M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Low coverage edge remover triggered 1889 times
#   0:01:31.228   195M / 621M  INFO    General                 (simplification.cpp        : 388)   PROCEDURE == Simplification cycle, iteration 4
#   0:01:31.228   195M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Tip clipper
#   0:01:31.229   195M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Tip clipper triggered 34 times
#   0:01:31.229   195M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Bulge remover
#   0:01:31.281   195M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Bulge remover triggered 17 times
#   0:01:31.282   195M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Low coverage edge remover
#   0:01:31.292   193M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Low coverage edge remover triggered 1039 times
#   0:01:31.292   193M / 621M  INFO    General                 (simplification.cpp        : 388)   PROCEDURE == Simplification cycle, iteration 5
#   0:01:31.292   193M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Tip clipper
#   0:01:31.293   193M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Tip clipper triggered 9 times
#   0:01:31.293   193M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Bulge remover
#   0:01:31.319   193M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Bulge remover triggered 11 times
#   0:01:31.319   193M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Low coverage edge remover
#   0:01:31.325   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Low coverage edge remover triggered 497 times
#   0:01:31.325   191M / 621M  INFO    General                 (simplification.cpp        : 388)   PROCEDURE == Simplification cycle, iteration 6
#   0:01:31.325   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Tip clipper
#   0:01:31.326   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Tip clipper triggered 3 times
#   0:01:31.326   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Bulge remover
#   0:01:31.336   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Bulge remover triggered 5 times
#   0:01:31.336   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Low coverage edge remover
#   0:01:31.339   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Low coverage edge remover triggered 324 times
#   0:01:31.339   191M / 621M  INFO    General                 (simplification.cpp        : 388)   PROCEDURE == Simplification cycle, iteration 7
#   0:01:31.339   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Tip clipper
#   0:01:31.339   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Tip clipper triggered 1 times
#   0:01:31.339   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Bulge remover
#   0:01:31.346   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Bulge remover triggered 5 times
#   0:01:31.346   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Low coverage edge remover
#   0:01:31.348   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Low coverage edge remover triggered 205 times
#   0:01:31.348   191M / 621M  INFO    General                 (simplification.cpp        : 388)   PROCEDURE == Simplification cycle, iteration 8
#   0:01:31.348   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Tip clipper
#   0:01:31.348   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Tip clipper triggered 0 times
#   0:01:31.348   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Bulge remover
#   0:01:31.352   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Bulge remover triggered 3 times
#   0:01:31.352   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Low coverage edge remover
#   0:01:31.354   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Low coverage edge remover triggered 211 times
#   0:01:31.354   191M / 621M  INFO    General                 (simplification.cpp        : 388)   PROCEDURE == Simplification cycle, iteration 9
#   0:01:31.354   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Tip clipper
#   0:01:31.354   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Tip clipper triggered 0 times
#   0:01:31.355   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Bulge remover
#   0:01:31.359   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Bulge remover triggered 5 times
#   0:01:31.359   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Low coverage edge remover
#   0:01:31.360   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Low coverage edge remover triggered 133 times
#   0:01:31.360   191M / 621M  INFO    General                 (simplification.cpp        : 388)   PROCEDURE == Simplification cycle, iteration 10
#   0:01:31.360   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Tip clipper
#   0:01:31.361   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Tip clipper triggered 1 times
#   0:01:31.361   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Bulge remover
#   0:01:31.363   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Bulge remover triggered 3 times
#   0:01:31.363   191M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Low coverage edge remover
#   0:01:31.366   190M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Low coverage edge remover triggered 117 times
#   0:01:31.366   190M / 621M  INFO    General                 (simplification.cpp        : 388)   PROCEDURE == Simplification cycle, iteration 11
#   0:01:31.366   190M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Tip clipper
#   0:01:31.375   190M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Tip clipper triggered 3 times
#   0:01:31.375   190M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Bulge remover
#   0:01:31.408   190M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Bulge remover triggered 3 times
#   0:01:31.408   190M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Low coverage edge remover
#   0:01:31.416   190M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Low coverage edge remover triggered 0 times
#   0:01:31.416   190M / 621M  INFO    General                 (simplification.cpp        : 388)   PROCEDURE == Simplification cycle, iteration 12
#   0:01:31.416   190M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Tip clipper
#   0:01:31.417   190M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Tip clipper triggered 0 times
#   0:01:31.417   190M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Bulge remover
#   0:01:31.417   190M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Bulge remover triggered 0 times
#   0:01:31.417   190M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Low coverage edge remover
#   0:01:31.417   190M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Low coverage edge remover triggered 0 times
#   0:01:31.424   190M / 621M  INFO   StageManager             (stage.cpp                 : 166)   STAGE == Simplification Cleanup
#   0:01:31.425   190M / 621M  INFO    General                 (simplification.cpp        : 196)   PROCEDURE == Post simplification
#   0:01:31.425   190M / 621M  INFO    General                 (graph_simplification.hpp  : 456)   Disconnection of relatively low covered edges disabled
#   0:01:31.425   190M / 621M  INFO    General                 (graph_simplification.hpp  : 493)   Complex tip clipping disabled
#   0:01:31.425   190M / 621M  INFO    General                 (graph_simplification.hpp  : 643)   Creating parallel br instance
#   0:01:31.425   190M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Tip clipper
#   0:01:31.434   190M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Tip clipper triggered 0 times
#   0:01:31.435   190M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Bulge remover
#   0:01:31.471   190M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Bulge remover triggered 0 times
#   0:01:31.471   190M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Tip clipper
#   0:01:31.481   190M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Tip clipper triggered 0 times
#   0:01:31.481   190M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Bulge remover
#   0:01:31.514   189M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Bulge remover triggered 0 times
#   0:01:31.514   189M / 621M  INFO    General                 (simplification.cpp        : 343)   Disrupting self-conjugate edges
#   0:01:31.533   189M / 621M  INFO   Simplification           (parallel_processing.hpp   : 165)   Running Removing isolated edges
#   0:01:31.554   188M / 621M  INFO   Simplification           (parallel_processing.hpp   : 167)   Removing isolated edges triggered 3570 times
#   0:01:31.554   188M / 621M  INFO    General                 (simplification.cpp        : 496)   Counting average coverage
#   0:01:31.564   188M / 621M  INFO    General                 (simplification.cpp        : 502)   Average coverage = 3.45038
#   0:01:31.564   188M / 621M  WARN    General                 (simplification.cpp        : 505)   The determined erroneous connection coverage threshold may be determined improperly
#   0:01:31.564   188M / 621M  INFO   StageManager             (stage.cpp                 : 166)   STAGE == Contig Output
#   0:01:31.567   188M / 621M  INFO    General                 (read_converter.cpp        : 102)   Outputting contigs to /home/jovyan/compbio-labs/assembly/spades/K21/simplified_contigs
#   0:01:31.579   192M / 621M  INFO    General                 (binary_converter.cpp      : 111)   8945 reads written
#   0:01:31.602   192M / 621M  INFO    General                 (pipeline.cpp              : 259)   SPAdes finished
#   0:01:31.629   155M / 621M  INFO    General                 (main.cpp                  : 107)   Assembling time: 0 hours 1 minutes 31 seconds
#
# ===== K21 finished.
#
#
# ===== K33 started.
#
#
# == Running: /opt/conda/bin/spades-core /home/jovyan/compbio-labs/assembly/spades/K33/configs/config.info
#
# WARNING: Try to use logger before create one. Level=INFO. Message=Additional contigs is /home/jovyan/compbio-labs/assembly/spades/K21/simplified_contigs
#   0:00:00.000     4M / 12M   INFO    General                 (main.cpp                  :  75)   Loaded config from /home/jovyan/compbio-labs/assembly/spades/K33/configs/config.info
#   0:00:00.000     4M / 12M   INFO    General                 (memory_limit.cpp          :  49)   Memory limit set to 51 Gb
#   0:00:00.000     4M / 12M   INFO    General                 (main.cpp                  :  85)   Starting SPAdes, built from N/A, git revision N/A
#   0:00:00.000     4M / 12M   INFO    General                 (main.cpp                  :  86)   Maximum k-mer length: 128
#   0:00:00.000     4M / 12M   INFO    General                 (main.cpp                  :  87)   Assembling dataset (/home/jovyan/compbio-labs/assembly/spades/dataset.info) with K=33
#   0:00:00.000     4M / 12M   INFO    General                 (main.cpp                  :  88)   Maximum # of threads to use (adjusted due to OMP capabilities): 4
#   0:00:00.000     4M / 12M   INFO    General                 (pipeline.cpp              : 194)   SPAdes started
#   0:00:00.000     4M / 12M   INFO    General                 (pipeline.cpp              : 201)   Starting from stage: read_conversion
#   0:00:00.000     4M / 12M   INFO    General                 (pipeline.cpp              : 207)   Two-step RR enabled: 0
#   0:00:00.000     4M / 12M   INFO   StageManager             (stage.cpp                 : 166)   STAGE == Binary Read Conversion
#   0:00:00.001     4M / 12M   INFO    General                 (read_converter.cpp        :  53)   Binary reads detected
#   0:00:00.002     4M / 12M   INFO    General                 (read_converter.cpp        :  53)   Binary reads detected
#   0:00:00.003     4M / 12M   INFO   StageManager             (stage.cpp                 : 166)   STAGE == de Bruijn graph construction
#   0:00:00.003     4M / 12M   INFO    General                 (construction.cpp          : 115)   Contigs from previous K will be used: /home/jovyan/compbio-labs/assembly/spades/K21/simplified_contigs
#   0:00:00.012     4M / 12M   INFO    General                 (construction.cpp          : 150)   Max read length 300
#   0:00:00.012     4M / 12M   INFO    General                 (construction.cpp          : 156)   Average read length 298.125
#   0:00:00.012     4M / 12M   INFO    General                 (stage.cpp                 : 113)   PROCEDURE == k+1-mer counting
#   0:00:00.014     4M / 12M   INFO    General                 (kmer_index_builder.hpp    : 117)   Splitting kmer instances into 16 files using 4 threads. This might take a while.
#   0:00:00.016     4M / 12M   INFO    General                 (file_limit.hpp            :  32)   Open file limit set to 1048576
#   0:00:00.016     4M / 12M   INFO    General                 (kmer_splitters.hpp        :  89)   Memory available for splitting buffers: 4.24995 Gb
#   0:00:00.016     4M / 12M   INFO    General                 (kmer_splitters.hpp        :  97)   Using cell size of 2097152
#   0:00:03.330     3G / 3G    INFO    General                 (kmer_splitters.hpp        : 287)   Processed 241292 reads
#   0:00:03.364    11M / 645M  INFO    General                 (kmer_splitters.hpp        : 293)   Used 241292 reads
#   0:00:03.364    11M / 645M  INFO    General                 (kmer_index_builder.hpp    : 120)   Starting k-mer counting.
#   0:00:05.786    11M / 645M  INFO    General                 (kmer_index_builder.hpp    : 127)   K-mer counting done. There are 22694253 kmers in total.
#   0:00:05.787    11M / 645M  INFO    General                 (kmer_index_builder.hpp    : 133)   Merging temporary buckets.
#   0:00:08.593    11M / 645M  INFO    General                 (stage.cpp                 : 113)   PROCEDURE == Extension index construction
#   0:00:08.596    11M / 645M  INFO   K-mer Index Building     (kmer_index_builder.hpp    : 301)   Building kmer index
#   0:00:08.596    11M / 645M  INFO    General                 (kmer_index_builder.hpp    : 117)   Splitting kmer instances into 64 files using 4 threads. This might take a while.
#   0:00:08.598    11M / 645M  INFO    General                 (file_limit.hpp            :  32)   Open file limit set to 1048576
#   0:00:08.598    11M / 645M  INFO    General                 (kmer_splitters.hpp        :  89)   Memory available for splitting buffers: 4.24992 Gb
#   0:00:08.598    11M / 645M  INFO    General                 (kmer_splitters.hpp        :  97)   Using cell size of 524288
#   0:00:13.509     3G / 3G    INFO    General                 (kmer_splitters.hpp        : 364)   Processed 22694253 kmers
#   0:00:13.509     3G / 3G    INFO    General                 (kmer_splitters.hpp        : 369)   Used 22694253 kmers.
#   0:00:13.566    11M / 838M  INFO    General                 (kmer_index_builder.hpp    : 120)   Starting k-mer counting.
#   0:00:15.759    11M / 838M  INFO    General                 (kmer_index_builder.hpp    : 127)   K-mer counting done. There are 22644214 kmers in total.
#   0:00:15.760    11M / 838M  INFO    General                 (kmer_index_builder.hpp    : 133)   Merging temporary buckets.
#   0:00:18.149    11M / 838M  INFO   K-mer Index Building     (kmer_index_builder.hpp    : 314)   Building perfect hash indices
#   0:00:19.806    29M / 838M  INFO    General                 (kmer_index_builder.hpp    : 150)   Merging final buckets.
#   0:00:22.478    29M / 838M  INFO   K-mer Index Building     (kmer_index_builder.hpp    : 336)   Index built. Total 10508248 bytes occupied (3.71247 bits per kmer).
#   0:00:22.500    53M / 838M  INFO   DeBruijnExtensionIndexBu (kmer_extension_index_build:  99)   Building k-mer extensions from k+1-mers
#   0:00:26.471    53M / 838M  INFO   DeBruijnExtensionIndexBu (kmer_extension_index_build: 103)   Building k-mer extensions from k+1-mers finished.
#   0:00:26.474    53M / 838M  INFO    General                 (stage.cpp                 : 113)   PROCEDURE == Early tip clipping
#   0:00:26.474    53M / 838M  INFO    General                 (construction.cpp          : 293)   Early tip clipper length bound set as (RL - K)
#   0:00:26.474    53M / 838M  INFO   Early tip clipping       (early_simplification.hpp  :  28)   Early tip clipping
#   0:00:30.546    55M / 838M  INFO   Early tip clipping       (early_simplification.hpp  :  63)   #tipped junctions: 74140
#   0:00:30.563    55M / 838M  INFO   Early tip clipping       (early_simplification.hpp  :  74)   Clipped tips: 80222
#   0:00:30.577    55M / 838M  INFO   Early tip clipping       (early_simplification.hpp  :  30)   11611615 34-mers were removed by early tip clipper
#   0:00:30.577    55M / 838M  INFO    General                 (stage.cpp                 : 113)   PROCEDURE == Condensing graph
#   0:00:30.599    55M / 838M  INFO   UnbranchingPathExtractor (debruijn_graph_constructor: 354)   Extracting unbranching paths
#   0:00:34.166    70M / 838M  INFO   UnbranchingPathExtractor (debruijn_graph_constructor: 373)   Extracting unbranching paths finished. 190802 sequences extracted
#   0:00:35.533    76M / 838M  INFO   UnbranchingPathExtractor (debruijn_graph_constructor: 309)   Collecting perfect loops
#   0:00:36.518    76M / 838M  INFO   UnbranchingPathExtractor (debruijn_graph_constructor: 342)   Collecting perfect loops finished. 2 loops collected
#   0:00:36.712   117M / 838M  INFO    General                 (stage.cpp                 : 113)   PROCEDURE == Filling coverage indices (PHM)
#   0:00:36.712   117M / 838M  INFO   K-mer Index Building     (kmer_index_builder.hpp    : 301)   Building kmer index
#   0:00:36.712   117M / 838M  INFO   K-mer Index Building     (kmer_index_builder.hpp    : 314)   Building perfect hash indices
#   0:00:38.153   128M / 838M  INFO   K-mer Index Building     (kmer_index_builder.hpp    : 336)   Index built. Total 10525400 bytes occupied (3.71033 bits per kmer).
#   0:00:38.206   224M / 838M  INFO    General                 (construction.cpp          : 429)   Collecting k-mer coverage information from reads, this takes a while.
#   0:00:40.485   221M / 838M  INFO    General                 (construction.cpp          : 549)   Filling coverage and flanking coverage from PHM
#   0:00:42.426   221M / 838M  INFO    General                 (construction.cpp          : 505)   Processed 381604 edges
# ...
#   0:03:26.932     2G / 4G    INFO   PairInfoImprover         (pair_info_improver.hpp    : 103)   Paired info stats: missing = 0; contradictional = 0
#   0:03:26.932     2G / 4G    INFO    General                 (distance_estimation.cpp   : 104)   Filling scaffolding index
#   0:03:26.932     2G / 4G    INFO   DistanceEstimator        (distance_estimation.hpp   : 116)   Using SMOOTHING distance estimator
#   0:03:26.934     2G / 4G    INFO    General                 (distance_estimation.cpp   :  35)   Filtering info
#   0:03:26.934     2G / 4G    INFO    General                 (pair_info_filters.hpp     : 242)   Start filtering; index size: 1866
#   0:03:26.935     2G / 4G    INFO    General                 (pair_info_filters.hpp     : 263)   Done filtering
#   0:03:26.935     2G / 4G    INFO    General                 (distance_estimation.cpp   : 183)   Clearing raw paired index
#   0:03:26.936     2G / 4G    INFO   StageManager             (stage.cpp                 : 166)   STAGE == Repeat Resolving
#   0:03:26.936     2G / 4G    INFO    General                 (repeat_resolving.cpp      :  69)   Using Path-Extend repeat resolving
#   0:03:26.936     2G / 4G    INFO    General                 (launcher.cpp              : 538)   ExSPAnder repeat resolving tool started
#   0:03:26.940     2G / 4G    INFO    General                 (coverage_uniformity_analyz:  25)   genomic coverage is 0.413028 calculated of length 5141001
#   0:03:26.941     2G / 4G    INFO    General                 (launcher.cpp              : 180)   Autodetecting unique edge set parameters...
#   0:03:26.941     2G / 4G    INFO    General                 (launcher.cpp              : 182)   Minimal unique edge length set to the smallest MP library IS: 2000
#   0:03:26.942     2G / 4G    INFO    General                 (coverage_uniformity_analyz:  25)   genomic coverage is 0.409621 calculated of length 5080968
#   0:03:26.943     2G / 4G    INFO    General                 (launcher.cpp              : 188)   median coverage for edges longer than 2000 is 0.409621 uniformity 91%
#   0:03:26.946     2G / 4G    INFO   ScaffoldingUniqueEdgeAna (scaff_supplementary.cpp   :  56)   With length cutoff: 2000, median long edge coverage: 0.411836, and maximal unique coverage: 0.5
#   0:03:26.946     2G / 4G    INFO   ScaffoldingUniqueEdgeAna (scaff_supplementary.cpp   :  57)   Unique edges quantity: 688, unique edges length 9298914, total edges length 10691722
#   0:03:26.951     2G / 4G    INFO    General                 (launcher.cpp              : 404)   Creating main extenders, unique edge length = 2000
#   0:03:26.952     2G / 4G    INFO    General                 (launcher.cpp              : 336)   filling path container
#   0:03:26.953     2G / 4G    INFO    General                 (extenders_logic.cpp       : 311)   Estimated coverage of library #0 is 1.03461
#   0:03:26.954     2G / 4G    INFO    General                 (extenders_logic.cpp       : 311)   Estimated coverage of library #0 is 1.03461
#   0:03:26.957     2G / 4G    INFO    General                 (extenders_logic.cpp       :  35)   resolvable_repeat_length_bound set to 35392
#   0:03:26.961     2G / 4G    INFO    General                 (extenders_logic.cpp       : 519)   Using 1 paired-end library
#   0:03:26.961     2G / 4G    INFO    General                 (extenders_logic.cpp       : 520)   Using 1 paired-end scaffolding library
#   0:03:26.962     2G / 4G    INFO    General                 (extenders_logic.cpp       : 521)   Using 1 single read library
#   0:03:26.963     2G / 4G    INFO    General                 (launcher.cpp              : 371)   Filling backbone edges for long reads scaffolding...
#   0:03:26.963     2G / 4G    INFO    General                 (launcher.cpp              : 390)    with coverage
#   0:03:26.964     2G / 4G    INFO   ScaffoldingUniqueEdgeAna (scaff_supplementary.cpp   :  56)   With length cutoff: 500, median long edge coverage: 0.416308, and maximal unique coverage: 0.5
#   0:03:26.965     2G / 4G    INFO   ScaffoldingUniqueEdgeAna (scaff_supplementary.cpp   :  57)   Unique edges quantity: 734, unique edges length 9371846, total edges length 10691722
#   0:03:26.965     2G / 4G    INFO    General                 (launcher.cpp              : 393)   734 unique edges
#   0:03:26.965     2G / 4G    INFO    General                 (extenders_logic.cpp       : 396)   Creating scaffolding extender for lib 1
#   0:03:26.965     2G / 4G    INFO   ExtensionChooser2015     (extension_chooser2015.hpp :  51)   ExtensionChooser2015 created
#   0:03:26.967     2G / 4G    INFO    General                 (extenders_logic.cpp       : 422)   Using 1 long reads scaffolding library
#   0:03:26.967     2G / 4G    INFO    General                 (launcher.cpp              : 432)   Total number of extenders is 5
#   0:03:26.968     2G / 4G    INFO    General                 (path_extender.hpp         : 894)   Processed 0 paths from 916 (0%)
#   0:03:26.979     2G / 4G    INFO    General                 (path_extender.hpp         : 894)   Processed 92 paths from 916 (10%)
#   0:03:26.984     2G / 4G    INFO    General                 (path_extender.hpp         : 892)   Processed 128 paths from 916 (13%)
#   0:03:26.991     2G / 4G    INFO    General                 (path_extender.hpp         : 894)   Processed 184 paths from 916 (20%)
#   0:03:26.998     2G / 4G    INFO    General                 (path_extender.hpp         : 892)   Processed 256 paths from 916 (27%)
#   0:03:27.000     2G / 4G    INFO    General                 (path_extender.hpp         : 894)   Processed 276 paths from 916 (30%)
#   0:03:27.008     2G / 4G    INFO    General                 (path_extender.hpp         : 894)   Processed 368 paths from 916 (40%)
#   0:03:27.015     2G / 4G    INFO    General                 (path_extender.hpp         : 894)   Processed 460 paths from 916 (50%)
#   0:03:27.020     2G / 4G    INFO    General                 (path_extender.hpp         : 892)   Processed 512 paths from 916 (55%)
#   0:03:27.023     2G / 4G    INFO    General                 (path_extender.hpp         : 894)   Processed 552 paths from 916 (60%)
#   0:03:27.029     2G / 4G    INFO    General                 (path_extender.hpp         : 894)   Processed 644 paths from 916 (70%)
#   0:03:27.035     2G / 4G    INFO    General                 (path_extender.hpp         : 894)   Processed 736 paths from 916 (80%)
#   0:03:27.042     2G / 4G    INFO    General                 (path_extender.hpp         : 894)   Processed 828 paths from 916 (90%)
#   0:03:27.048     2G / 4G    INFO    General                 (launcher.cpp              : 244)   Finalizing paths
#   0:03:27.048     2G / 4G    INFO    General                 (launcher.cpp              : 246)   Deduplicating paths
#   0:03:27.051     2G / 4G    INFO    General                 (launcher.cpp              : 250)   Paths deduplicated
#   0:03:27.051     2G / 4G    INFO   PEResolver               (pe_resolver.hpp           : 295)   Removing overlaps
#   0:03:27.051     2G / 4G    INFO   PEResolver               (pe_resolver.hpp           : 298)   Sorting paths
#   0:03:27.052     2G / 4G    INFO   PEResolver               (pe_resolver.hpp           : 305)   Marking overlaps
#   0:03:27.052     2G / 4G    INFO   OverlapRemover           (pe_resolver.hpp           : 130)   Marking start/end overlaps
#   0:03:27.054     2G / 4G    INFO   OverlapRemover           (pe_resolver.hpp           : 133)   Marking remaining overlaps
#   0:03:27.055     2G / 4G    INFO   PEResolver               (pe_resolver.hpp           : 308)   Splitting paths
#   0:03:27.056     2G / 4G    INFO   PEResolver               (pe_resolver.hpp           : 313)   Deduplicating paths
#   0:03:27.056     2G / 4G    INFO   PEResolver               (pe_resolver.hpp           : 315)   Overlaps removed
#   0:03:27.058     2G / 4G    INFO    General                 (launcher.cpp              : 267)   Paths finalized
#   0:03:27.058     2G / 4G    INFO    General                 (launcher.cpp              : 439)   Closing gaps in paths
#   0:03:27.063     2G / 4G    INFO    General                 (launcher.cpp              : 467)   Gap closing completed
#   0:03:27.065     2G / 4G    INFO    General                 (launcher.cpp              : 296)   Traversing tandem repeats
#   0:03:27.074     2G / 4G    INFO    General                 (launcher.cpp              : 306)   Traversed 0 loops
#   0:03:27.074     2G / 4G    INFO    General                 (launcher.cpp              : 244)   Finalizing paths
#   0:03:27.074     2G / 4G    INFO    General                 (launcher.cpp              : 246)   Deduplicating paths
#   0:03:27.075     2G / 4G    INFO    General                 (launcher.cpp              : 250)   Paths deduplicated
#   0:03:27.075     2G / 4G    INFO   PEResolver               (pe_resolver.hpp           : 295)   Removing overlaps
#   0:03:27.075     2G / 4G    INFO   PEResolver               (pe_resolver.hpp           : 298)   Sorting paths
#   0:03:27.075     2G / 4G    INFO   PEResolver               (pe_resolver.hpp           : 305)   Marking overlaps
#   0:03:27.075     2G / 4G    INFO   OverlapRemover           (pe_resolver.hpp           : 130)   Marking start/end overlaps
#   0:03:27.076     2G / 4G    INFO   OverlapRemover           (pe_resolver.hpp           : 133)   Marking remaining overlaps
#   0:03:27.078     2G / 4G    INFO   PEResolver               (pe_resolver.hpp           : 308)   Splitting paths
#   0:03:27.078     2G / 4G    INFO   PEResolver               (pe_resolver.hpp           : 313)   Deduplicating paths
#   0:03:27.078     2G / 4G    INFO   PEResolver               (pe_resolver.hpp           : 315)   Overlaps removed
#   0:03:27.080     2G / 4G    INFO    General                 (launcher.cpp              : 267)   Paths finalized
#   0:03:27.080     2G / 4G    INFO    General                 (launcher.cpp              : 596)   ExSPAnder repeat resolving tool finished
#   0:03:27.084     2G / 4G    INFO   StageManager             (stage.cpp                 : 166)   STAGE == Contig Output
#   0:03:27.084     2G / 4G    INFO    General                 (contig_output.hpp         :  21)   Outputting contigs to /home/jovyan/compbio-labs/assembly/spades/K127/before_rr.fasta
#   0:03:27.176     2G / 4G    INFO    General                 (contig_output_stage.cpp   : 146)   Writing GFA graph to /home/jovyan/compbio-labs/assembly/spades/K127/assembly_graph_with_scaffolds.gfa
#   0:03:27.228     2G / 4G    INFO    General                 (contig_output_stage.cpp   : 160)   Outputting FastG graph to /home/jovyan/compbio-labs/assembly/spades/K127/assembly_graph.fastg
#   0:03:27.511     2G / 4G    INFO    General                 (contig_output_stage.cpp   : 190)   Breaking scaffolds
#   0:03:27.562     2G / 4G    INFO    General                 (contig_output_stage.cpp   :  95)   Outputting contigs to /home/jovyan/compbio-labs/assembly/spades/K127/final_contigs.fasta
#   0:03:27.647     2G / 4G    INFO    General                 (contig_output_stage.cpp   : 101)   Outputting FastG paths to /home/jovyan/compbio-labs/assembly/spades/K127/final_contigs.paths
#   0:03:27.703     2G / 4G    INFO    General                 (contig_output_stage.cpp   :  95)   Outputting contigs to /home/jovyan/compbio-labs/assembly/spades/K127/scaffolds.fasta
#   0:03:27.789     2G / 4G    INFO    General                 (contig_output_stage.cpp   : 101)   Outputting FastG paths to /home/jovyan/compbio-labs/assembly/spades/K127/scaffolds.paths
#   0:03:27.794     2G / 4G    INFO    General                 (contig_output_stage.cpp   : 108)   Populating GFA with scaffold paths
#   0:03:27.828     2G / 4G    INFO    General                 (pipeline.cpp              : 259)   SPAdes finished
#   0:03:27.911     2G / 4G    INFO    General                 (main.cpp                  : 107)   Assembling time: 0 hours 3 minutes 27 seconds
#
# ===== K127 finished.
#
#
# ===== Copy files started.
#
#
# == Running: /opt/conda/bin/python /opt/conda/share/spades/spades_pipeline/scripts/copy_files.py /home/jovyan/compbio-labs/assembly/spades/K127/before_rr.fasta /home/jovyan/compbio-labs/assembly/spades/before_rr.fasta /home/jovyan/compbio-labs/assembly/spades/K127/assembly_graph_after_simplification.gfa /home/jovyan/compbio-labs/assembly/spades/assembly_graph_after_simplification.gfa /home/jovyan/compbio-labs/assembly/spades/K127/final_contigs.fasta /home/jovyan/compbio-labs/assembly/spades/contigs.fasta /home/jovyan/compbio-labs/assembly/spades/K127/first_pe_contigs.fasta /home/jovyan/compbio-labs/assembly/spades/first_pe_contigs.fasta /home/jovyan/compbio-labs/assembly/spades/K127/strain_graph.gfa /home/jovyan/compbio-labs/assembly/spades/strain_graph.gfa /home/jovyan/compbio-labs/assembly/spades/K127/scaffolds.fasta /home/jovyan/compbio-labs/assembly/spades/scaffolds.fasta /home/jovyan/compbio-labs/assembly/spades/K127/scaffolds.paths /home/jovyan/compbio-labs/assembly/spades/scaffolds.paths /home/jovyan/compbio-labs/assembly/spades/K127/assembly_graph_with_scaffolds.gfa /home/jovyan/compbio-labs/assembly/spades/assembly_graph_with_scaffolds.gfa /home/jovyan/compbio-labs/assembly/spades/K127/assembly_graph.fastg /home/jovyan/compbio-labs/assembly/spades/assembly_graph.fastg /home/jovyan/compbio-labs/assembly/spades/K127/final_contigs.paths /home/jovyan/compbio-labs/assembly/spades/contigs.paths
# ===== Copy files finished.
#
#
# ===== Assembling finished.
#
#
# ===== Breaking scaffolds started.
#
#
# == Running: /opt/conda/bin/python /opt/conda/share/spades/spades_pipeline/scripts/breaking_scaffolds_script.py --result_scaffolds_filename /home/jovyan/compbio-labs/assembly/spades/scaffolds.fasta --misc_dir /home/jovyan/compbio-labs/assembly/spades/misc --threshold_for_breaking_scaffolds 3
#
#
# ===== Breaking scaffolds finished.
#
#
# ===== Terminate started.
#
#
# ===== Terminate finished.
#
#  * Corrected reads are in /home/jovyan/compbio-labs/assembly/spades/corrected/
#  * Assembled contigs are in /home/jovyan/compbio-labs/assembly/spades/contigs.fasta
#  * Assembled scaffolds are in /home/jovyan/compbio-labs/assembly/spades/scaffolds.fasta
#  * Paths in the assembly graph corresponding to the contigs are in /home/jovyan/compbio-labs/assembly/spades/contigs.paths
#  * Paths in the assembly graph corresponding to the scaffolds are in /home/jovyan/compbio-labs/assembly/spades/scaffolds.paths
#  * Assembly graph is in /home/jovyan/compbio-labs/assembly/spades/assembly_graph.fastg
#  * Assembly graph in GFA format is in /home/jovyan/compbio-labs/assembly/spades/assembly_graph_with_scaffolds.gfa
#
# ======= SPAdes pipeline finished WITH WARNINGS!
#
# === Error correction and assembling warnings:
#  * 0:00:38.767   251M / 621M  WARN    General                 (kmer_coverage_model.cpp   : 366)   Failed to determine erroneous kmer threshold. Threshold set to: 35
#  * 0:01:31.564   188M / 621M  WARN    General                 (simplification.cpp        : 505)   The determined erroneous connection coverage threshold may be determined improperly
#  * 0:00:42.544   101M / 838M  WARN    General                 (kmer_coverage_model.cpp   : 218)   Too many erroneous kmers, the estimates might be unreliable
#  * 0:00:44.243   101M / 838M  WARN    General                 (kmer_coverage_model.cpp   : 366)   Failed to determine erroneous kmer threshold. Threshold set to: 28
#  * 0:00:58.445   111M / 2G    WARN    General                 (kmer_coverage_model.cpp   : 366)   Failed to determine erroneous kmer threshold. Threshold set to: 24
#  * 0:00:59.182   101M / 2G    WARN    General                 (kmer_coverage_model.cpp   : 366)   Failed to determine erroneous kmer threshold. Threshold set to: 17
#  * 0:00:49.928    96M / 2G    WARN    General                 (kmer_coverage_model.cpp   : 366)   Failed to determine erroneous kmer threshold. Threshold set to: 12
# ======= Warnings saved to /home/jovyan/compbio-labs/assembly/spades/warnings.log
#
# SPAdes log can be found here: /home/jovyan/compbio-labs/assembly/spades/spades.log
#
# Thank you for using SPAdes!
